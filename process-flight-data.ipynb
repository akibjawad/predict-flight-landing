# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from openpyxl) (1.1.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn import tree
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

pd.options.display.float_format = '{:,.2f}'.format

# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import display, HTML
# Out:
# /var/folders/k7/38v84p457m70dh2vksct50j80000gn/T/ipykernel_17774/4262510003.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
from datetime import datetime

def to_minutes(x):
    h,m = x.split(':')
    return int(h)*60 + int(m)

def findDayOfWeek(dateStr):
    date_object = datetime.strptime(dateStr, '%m/%d/%Y')
    dayOfWeek = date_object.strftime('%A')
    return dayOfWeek 

# findDayOfWeek('01/01/2006')

def flightNoStr(x):
    return str(int(x))

def classifyDelay(delay):
    if delay < -5:
        return 0 #flight is early
    elif delay > 5:
        return 1 #flight is delayed
    else:
        return 2 #flight is ontime
# def calculateDepTime()

# %%
# jetblue_B6_116_dep_time_range = (735, 885) #13:25= 13*60+25 - 70 min buffer or 13:35 = 13*60+35 + 70 minute buffer
import os, re, json
from pathlib import Path
from openpyxl import load_workbook
RawDataProcessing = True
airport_on_time_dep_pct = {}

# %%
# Airport on time departure percentage data
# Replace 'your_file.xlsx' with the path to your Excel file
file_path = 'data/airport-ranking-on-time-dep/airport-ranking-on-time-dep-train.xlsx'

# Load the Excel workbook
workbook = load_workbook(file_path)

# Get the names of all worksheets
sheet_names = workbook.sheetnames

# Read data from each worksheet
for sheet_name in sheet_names:
    # Access each worksheet by its name
    worksheet = workbook[sheet_name]

    if int(sheet_name) < 2006:
        continue
    # Print the name of the current worksheet
    print(f"Reading data from '{sheet_name}'")
    year = sheet_name #Sheet name is the year
    # airport_on_time_dep_pct[year]={} 
    
    # Iterate through all rows and columns
    it = 0
    airport_data = {}
    # airport_data['MCO'] = -1
    # airport_data['JFK'] = -1
    # airport_data['ORD'] = -1
    data_found = 0
    for row in worksheet.iter_rows(values_only=True):
        # if it < 3:
        #     it += 1
        #     continue
        # each row is a tuple, you can access each
        row_arr = list(row)
        # print(row_arr)
        # if len(row_arr) != 6:
        #     print('skipping metadata')
        #     it += 1
        #     continue;
            
        if it == 0:
            if year in row_arr[4]:
                print('file format is okay')
                it += 1
                continue
            else:
                print('Major error in the the format of this specific worksheet')
                break
        if 'Bureau of Transportation Statistics' in str(row):
            break
        
        airport_details = row_arr[4]
        # print(airport_details)
        match = re.search(r'\((.*?)\)', airport_details)
        if match:
            airport_code = match.group(1)
            airport_dep_pct = round(float(row_arr[5]), 2)
            if airport_code == 'MCO':
                airport_data[airport_code] = airport_dep_pct
                data_found += 1
            if airport_code == 'JFK':
                airport_data[airport_code] = airport_dep_pct
                data_found += 1
            if airport_code == 'ORD':
                airport_data[airport_code] = airport_dep_pct
                data_found += 1
        else:
            print("No substring found inside parentheses.")
        if data_found == 3:
            break;
        it += 1
    airport_on_time_dep_pct[year] = airport_data
        # print(airport_code)  # or process row data as needed

# Close the workbook
workbook.close()

# json.dump(airport_on_time_dep_pct, indent=4)
# Out:
# Reading data from '2023'
# file format is okay
# Reading data from '2022'
# file format is okay
# Reading data from '2021'
# file format is okay
# Reading data from '2020'
# file format is okay
# Reading data from '2019'
# file format is okay
# Reading data from '2018'
# file format is okay
# Reading data from '2017'
# file format is okay
# Reading data from '2016'
# file format is okay
# Reading data from '2015'
# file format is okay
# Reading data from '2014'
# file format is okay
# Reading data from '2013'
# file format is okay
# Reading data from '2012'
# file format is okay
# Reading data from '2011'
# file format is okay
# Reading data from '2010'
# file format is okay
# Reading data from '2009'
# file format is okay
# Reading data from '2008'
# file format is okay
# Reading data from '2007'
# file format is okay
# Reading data from '2006'
# file format is okay

# %%
# Airport on time departure percentage data
# Replace 'your_file.xlsx' with the path to your Excel file
file_path = 'data/airport-ranking-on-time-dep/airport-ranking-on-time-dep-test.xlsx'

# Load the Excel workbook
workbook = load_workbook(file_path)

# Get the names of all worksheets
sheet_names = workbook.sheetnames

# Read data from each worksheet
for sheet_name in sheet_names:
    # Access each worksheet by its name
    worksheet = workbook[sheet_name]

    if int(sheet_name) < 2006:
        continue
    # Print the name of the current worksheet
    print(f"Reading data from '{sheet_name}'")
    year = sheet_name #Sheet name is the year
    # airport_on_time_dep_pct[year]={} 
    
    # Iterate through all rows and columns
    it = 0
    airport_data = {}
    # airport_data['MCO'] = -1
    # airport_data['JFK'] = -1
    # airport_data['ORD'] = -1
    data_found = 0
    for row in worksheet.iter_rows(values_only=True):
        # if it < 3:
        #     it += 1
        #     continue
        # each row is a tuple, you can access each
        row_arr = list(row)
        # print(row_arr)
        # if len(row_arr) != 6:
        #     print('skipping metadata')
        #     it += 1
        #     continue;
            
        if it == 0:
            if year in row_arr[4]:
                print('file format is okay')
                it += 1
                continue
            else:
                print('Major error in the the format of this specific worksheet')
                break
        if 'Bureau of Transportation Statistics' in str(row):
            break
        
        airport_details = row_arr[4]
        # print(airport_details)
        match = re.search(r'\((.*?)\)', airport_details)
        if match:
            airport_code = match.group(1)
            airport_dep_pct = round(float(row_arr[5]), 2)
            if airport_code == 'MCO':
                airport_data[airport_code] = airport_dep_pct
                data_found += 1
            if airport_code == 'JFK':
                airport_data[airport_code] = airport_dep_pct
                data_found += 1
            if airport_code == 'ORD':
                airport_data[airport_code] = airport_dep_pct
                data_found += 1
        else:
            print("No substring found inside parentheses.")
        if data_found == 3:
            break;
        it += 1
    airport_on_time_dep_pct[year] = airport_data
        # print(airport_code)  # or process row data as needed

# Close the workbook
workbook.close()
# Out:
# Reading data from '2024'
# file format is okay

# %%
# Add airline arrival on time percentage column
with open('airport_on_time_dep_pct.json', 'w') as json_file:
    json.dump(airport_on_time_dep_pct, json_file, indent=4)

# json.dump(airport_on_time_dep_pct, indent=4)

# %%
import csv

list_of_airlines = []
airline_name_code_map = {}
dataDir = 'data/arrivals/'
fileNames = os.listdir(dataDir)
for file in fileNames:
    filePath = dataDir + file
    # print('Processing file {}'.format(filePath))
    if Path(filePath).is_dir():
        print('Skipping the directory {}'.format(filePath))
        continue
    airline_name = file.split('_')[0]
    list_of_airlines.append(airline_name)
    # airline_code = ''
    with open(filePath, 'r', newline='') as csv_file:
        # Create a CSV reader object
        csv_reader = csv.reader(csv_file)
        
        # Read the first row
        head_row = next(csv_reader)
        first_row = next(csv_reader)
        airline_code = first_row[0]
        airline_name_code_map[airline_name] = airline_code
        # Print the first row
        print(first_row)
print(list_of_airlines)
print(airline_name_code_map)
# Out:
# ['YV', '03/01/2006', '7245', 'N77195', 'IAD', '13:59', '13:51', '74', '76', '-8', '13:46', '5', '0', '0', '0', '0', '0']
# ['B6', '03/01/2006', '0022', 'N523JB', 'JFK', '23:59', '23:58', '64', '63', '-1', '23:54', '4', '0', '0', '0', '0', '0']
# ['9E', '03/01/2010', '3726', '85809E', 'DTW', '08:47', '08:43', '87', '79', '-4', '08:40', '3', '0', '0', '0', '0', '0']
# ['WN', '03/01/2022', '0207', 'N253WN', 'BWI', '13:10', '13:08', '75', '59', '-2', '13:06', '2', '0', '0', '0', '0', '0']
# ['UA', '03/01/2019', '0607', 'N803UA', 'ORD', '21:20', '21:40', '105', '94', '20', '21:37', '3', '1', '0', '0', '0', '19']
# ['OH', '03/01/2006', '5144', 'N592SW', 'CVG', '16:36', '16:33', '96', '93', '-3', '16:30', '3', '0', '0', '0', '0', '0']
# ['MQ', '03/01/2006', '3865', 'N523AE', 'DFW', '14:54', '15:10', '184', '195', '16', '15:06', '4', '0', '0', '16', '0', '0']
# ['OO', '03/01/2006', '5802', 'N760SK', 'ORD', '23:52', '23:41', '102', '94', '-11', '23:36', '5', '0', '0', '0', '0', '0']
# Skipping the directory data/arrivals/.ipynb_checkpoints
# ['YX', '03/01/2018', '3516', '', 'EWR', '22:52', '00:00', '82', '0', '0', '00:00', '0', '0', '0', '0', '0', '0']
# ['AA', '03/01/2016', '1971', 'N105UW', 'CLT', '00:11', '23:59', '106', '98', '-12', '23:56', '3', '0', '0', '0', '0', '0']
# ['DL', '03/01/2006', '0613', 'N943DL', 'ATL', '11:29', '11:42', '129', '141', '13', '11:36', '6', '0', '0', '0', '0', '0']
# ['Mesa', 'JetBlue', 'Endeavor', 'Southwest', 'United', 'PSA', 'Envoy', 'Skywest', 'Republic', 'American', 'Delta']
# {'Mesa': 'YV', 'JetBlue': 'B6', 'Endeavor': '9E', 'Southwest': 'WN', 'United': 'UA', 'PSA': 'OH', 'Envoy': 'MQ', 'Skywest': 'OO', 'Republic': 'YX', 'American': 'AA', 'Delta': 'DL'}

# %%
airline_on_time_arr_pct_data = {}

# %%
# Airport on time departure percentage data
# Replace 'your_file.xlsx' with the path to your Excel file
file_path = 'data/airline-on-time-arrival-pct/airline-on-time-pct-2023.xlsx'

# Load the Excel workbook
workbook = load_workbook(file_path)

# Get the names of all worksheets
sheet_names = workbook.sheetnames

# Read data from each worksheet
for sheet_name in sheet_names:
    # Access each worksheet by its name
    worksheet = workbook[sheet_name]
    print(f"Reading data from '{sheet_name}'")

    names = sheet_name.split()
    if len(names) > 1:
        if 'Marketing' in names[0]:
            print('Skipping this sheet, as it contains marketing on time arrival percentage')
            continue
        else:
            year = names[1]
    else:
        year = names[0]

    if int(year) < 2006:
        print('Skipping years earlier than 2006')
        continue

    # Iterate through all rows and columns
    it = 0
    airline_data = {}
    metadata_str = ['Reporting Operating Airline On-Time Arrival','On-Time Arrival Pct',
                    'Source: Bureau of Transportation Statistics', 'All Carriers',
                   'branded code-share partners', 'stopped codesharing', ' ceased operations',
                    'combined reporting', 'ranked based on', 'stopped reporting']
    for row in worksheet.iter_rows(values_only=True):
        row_str = " ".join(str(element) for element in row)
        
        skiprow = False
        for s in metadata_str:
            s = s.lower()
            if s in row_str.lower():
                skiprow= True
            if all(element == None for element in row):
                skiprow=True
        if skiprow:
            continue
        print(row_str)
        
        row_arr = list(row)
        
        airline_name = row_arr[1]
        
        if '*' in airline_name:
            airline_name = ''.join([char for char in airline_name if char != '*'])
            print('after removing start airline name {}'.format(airline_name))
        
        airline_name_first = airline_name.split()[0]

        substring_found = False
        
        for element in list_of_airlines:
            if airline_name_first.lower() == element.lower():
                airline_name_first = element
                substring_found = True
        
        # any(airline_name_first.lower() in element.lower() for element in list_of_airlines)
        
        if not substring_found:
            print('{} not in our dataset'.format(airline_name))
            continue
        
        airline_on_time_arrival_pct = round(float(row_arr[2]), 2)
        airline_data[airline_name_first] = airline_on_time_arrival_pct
    
    airline_on_time_arr_pct_data[year] = airline_data

# Close the workbook
workbook.close()
print(airline_on_time_arr_pct_data)
# json.dump(airport_on_time_dep_pct, indent=4)
# Out:
# Reading data from '2003'
# Skipping years earlier than 2006
# Reading data from '2004'
# Skipping years earlier than 2006
# Reading data from '2005'
# Skipping years earlier than 2006
# Reading data from '2006'
# 1 Hawaiian   93.75
# Hawaiian   not in our dataset
# 2 Aloha 89.97
# Aloha not in our dataset
# 3 Frontier 80.72
# Frontier not in our dataset
# 4 Southwest  80.23
# 5 US Airways 76.85
# US Airways not in our dataset
# 6 SkyWest   76.78
# 7 Delta  76.3
# 8 Northwest  75.82
# Northwest  not in our dataset
# 9 American   75.55
# 10 AirTran 74.62
# AirTran not in our dataset
# 11 United  73.86
# 12 Comair 73.77
# Comair not in our dataset
# 13 Continental  73.42
# Continental  not in our dataset
# 14 JetBlue  73.33
# 15 Alaska   73.28
# Alaska   not in our dataset
# 16 ExpressJet   73.28
# ExpressJet   not in our dataset
# 17 Mesa 72.9
# 18 American Eagle  71.48
# 19 ATA 69.44
# ATA not in our dataset
# 20 Atlantic Southeast  66
# Atlantic Southeast  not in our dataset
# None All Airlines 75.45
# All Airlines not in our dataset
# Reading data from '2007'
# 1 Hawaiian   93.29
# Hawaiian   not in our dataset
# 2 Aloha 92.25
# Aloha not in our dataset
# 3 Southwest  80.12
# 4 Frontier   77.61
# Frontier   not in our dataset
# 5 Delta  76.89
# 6 AirTran   76.81
# AirTran   not in our dataset
# 7 Pinnacle  76.3
# Pinnacle  not in our dataset
# 8 SkyWest   75.68
# 9 Continental  74.34
# Continental  not in our dataset
# 10 ExpressJet   73.77
# ExpressJet   not in our dataset
# 11 Mesa   73.1
# 12 Alaska   72.38
# Alaska   not in our dataset
# 13 United  70.33
# 14 JetBlue  70.1
# 15 Northwest  69.62
# Northwest  not in our dataset
# 16 American Eagle  69.13
# 17 American   68.74
# 18 US Airways 68.71
# US Airways not in our dataset
# 19 Comair  67.86
# Comair  not in our dataset
# 20 Atlantic Southeast  64.73
# Atlantic Southeast  not in our dataset
# None All Airlines 73.42
# All Airlines not in our dataset
# Reading data from '2008'
# 1 Hawaiian   89.97
# Hawaiian   not in our dataset
# 2 Southwest  80.48
# 3 US Airways 80.06
# US Airways not in our dataset
# 4 Pinnacle  79.55
# Pinnacle  not in our dataset
# 5 Frontier   78.98
# Frontier   not in our dataset
# 6 SkyWest   78.97
# 7 Alaska   78.29
# Alaska   not in our dataset
# 8 Northwest  76.77
# Northwest  not in our dataset
# 9 AirTran   76.73
# AirTran   not in our dataset
# 10 Delta  76.36
# 11 Atlantic Southeast  74.24
# Atlantic Southeast  not in our dataset
# 12 Continental  73.98
# Continental  not in our dataset
# 13 ExpressJet   73.57
# ExpressJet   not in our dataset
# 14 Mesa   72.95
# 15 JetBlue  72.87
# 16 American Eagle  72.85
# 17 United  71.61
# 18 Comair  69.92
# Comair  not in our dataset
# 19 American   69.84
# 20 Aloha*  94.33
# after removing start airline name Aloha
# Aloha  not in our dataset
# None All Airlines 76.04
# All Airlines not in our dataset
# Reading data from '2009'
# 1 Hawaiian   92.06 None None None None None None None
# Hawaiian   not in our dataset
# 2 Southwest  83 None None None None None None None
# 3 Alaska   82.91 None None None None None None None
# Alaska   not in our dataset
# 4 Pinnacle  82.54 None None None None None None None
# Pinnacle  not in our dataset
# 5 SkyWest   82.11 None None None None None None None
# 6 United  80.98 None None None None None None None
# 7 US Airways 80.87 None None None None None None None
# US Airways not in our dataset
# 8 Northwest  79.15 None None None None None None None
# Northwest  not in our dataset
# 9 Mesa   79.13 None None None None None None None
# 10 Continental  78.77 None None None None None None None
# Continental  not in our dataset
# 11 ExpressJet   78.72 None None None None None None None
# ExpressJet   not in our dataset
# 12 Delta  78.56 None None None None None None None
# 13 Frontier   78.3 None None None None None None None
# Frontier   not in our dataset
# 14 JetBlue  77.45 None None None None None None None
# 15 American Eagle  77.22 None None None None None None None
# 16 American   77.21 None None None None None None None
# 17 AirTran   75.79 None None None None None None None
# AirTran   not in our dataset
# 18 Atlantic Southeast  71.24 None None None None None None None
# Atlantic Southeast  not in our dataset
# 19 Comair  69.02 None None None None None None None
# Comair  not in our dataset
# None All Airlines 79.49 None None None None None None None
# All Airlines not in our dataset
# Reading data from '2010'
# 1 Hawaiian   92.47 None None None None None None None
# Hawaiian   not in our dataset
# 2 Alaska   87.56 None None None None None None None
# Alaska   not in our dataset
# 3 United  85.16 None None None None None None None
# 4 Mesa   83.32 None None None None None None None
# 5 US Airways 83.03 None None None None None None None
# US Airways not in our dataset
# 6 AirTran   82.84 None None None None None None None
# AirTran   not in our dataset
# 7 Continental  81.42 None None None None None None None
# Continental  not in our dataset
# 8 Frontier   81.41 None None None None None None None
# Frontier   not in our dataset
# 9 American   79.63 None None None None None None None
# 10 Southwest  79.46 None None None None None None None
# 11 Atlantic Southeast  79.24 None None None None None None None
# Atlantic Southeast  not in our dataset
# 12 SkyWest   79.05 None None None None None None None
# 13 Pinnacle  78.49 None None None None None None None
# Pinnacle  not in our dataset
# 14 ExpressJet   77.77 None None None None None None None
# ExpressJet   not in our dataset
# 15 Delta  77.37 None None None None None None None
# 16 American Eagle  77.05 None None None None None None None
# 17 JetBlue  75.68 None None None None None None None
# 18 Comair  73.12 None None None None None None None
# Comair  not in our dataset
# None All Airlines 79.79 None None None None None None None
# All Airlines not in our dataset
# Reading data from '2011'
# 1 Hawaiian   92.78 None None None None None None None
# Hawaiian   not in our dataset
# 2 Alaska   88.2 None None None None None None None
# Alaska   not in our dataset
# 3 AirTran   84.43 None None None None None None None
# AirTran   not in our dataset
# 4 Mesa   83.73 None None None None None None None
# 5 Continental  82.29 None None None None None None None
# Continental  not in our dataset
# 6 Southwest  81.33 None None None None None None None
# 7 United  80.16 None None None None None None None
# 8 US Airways 79.79 None None None None None None None
# US Airways not in our dataset
# 9 SkyWest   79.34 None None None None None None None
# 10 Frontier   79.16 None None None None None None None
# Frontier   not in our dataset
# 11 American   77.79 None None None None None None None
# 12 Atlantic Southeast  77.13 None None None None None None None
# Atlantic Southeast  not in our dataset
# 13 American Eagle  76.35 None None None None None None None
# 14 Delta  75.15 None None None None None None None
# 15 ExpressJet   74.67 None None None None None None None
# ExpressJet   not in our dataset
# 16 JetBlue  73.34 None None None None None None None
# None All Airlines 79.62 None None None None None None None
# All Airlines not in our dataset
# Reading data from '2012'
# 1 Hawaiian   93.38 None None None None None None None
# Hawaiian   not in our dataset
# 2 Alaska   87.52 None None None None None None None
# Alaska   not in our dataset
# 3 AirTran   87.09 None None None None None None None
# AirTran   not in our dataset
# 4 Delta  86.54 None None None None None None None
# 5 US Airways 85.88 None None None None None None None
# US Airways not in our dataset
# 6 Mesa   85 None None None None None None None
# 7 Virgin America 83.45 None None None None None None None
# Virgin America not in our dataset
# 8 Southwest  83.13 None None None None None None None
# 9 American Eagle  81.60565583125502 None None None None None None None
# 10 SkyWest   81.60552062626668 None None None None None None None
# 11 JetBlue  79.13 None None None None None None None
# 12 Frontier   77.93 None None None None None None None
# Frontier   not in our dataset
# 13 United  77.35 None None None None None None None
# 14 American   76.94 None None None None None None None
# 15 ExpressJet   76.89 None None None None None None None
# ExpressJet   not in our dataset
# None All Airlines 81.85 None None None None None None None
# All Airlines not in our dataset
# Reading data from '2013'
# 1 Hawaiian   93.32 None None None None None None None None None
# Hawaiian   not in our dataset
# 2 Alaska   87.16 None None None None None None None None None
# Alaska   not in our dataset
# 3 Delta  84.51 None None None None None None None None None
# 4 Virgin America 82.07 None None None None None None None None None
# Virgin America not in our dataset
# 5 US Airways 81.47 None None None None None None None None None
# US Airways not in our dataset
# 6 Endeavor 80.27 None None None None None None None None None
# 7 SkyWest   79.66 None None None None None None None None None
# 8 AirTran   79.45 None None None None None None None None None
# AirTran   not in our dataset
# 9 United  79.27 None None None None None None None None None
# 10 American   77.62 None None None None None None None None None
# 11 Mesa   77.39 None None None None None None None None None
# 12 Southwest  76.7 None None None None None None None None None
# 13 JetBlue  74.44 None None None None None None None None None
# 14 Frontier   73.08 None None None None None None None None None
# Frontier   not in our dataset
# 15 ExpressJet   72.75 None None None None None None None None None
# ExpressJet   not in our dataset
# 16 American Eagle  72.1 None None None None None None None None None
# None All Airlines 78.34 None None None None None None None None None
# All Airlines not in our dataset
# Reading data from '2014'
# 1 Hawaiian   91.89 None None None None
# Hawaiian   not in our dataset
# 2 Alaska   86.16 None None None None
# Alaska   not in our dataset
# 3 Delta  83.71 None None None None
# 4 Virgin America 81.48 None None None None
# Virgin America not in our dataset
# 5 AirTran   80.89 None None None None
# AirTran   not in our dataset
# 6 US Airways 80.69 None None None None
# US Airways not in our dataset
# 7 SkyWest   76.35 None None None None
# 8 United  75.99 None None None None
# 9 American   75.79 None None None None
# 10 JetBlue  75.43 None None None None
# 11 Frontier   74.07 None None None None
# Frontier   not in our dataset
# 12 Southwest  73.01 None None None None
# 13 ExpressJet   70.75 None None None None
# ExpressJet   not in our dataset
# 14 Envoy 68.79 None None None None
# None All Airlines 76.25 None None None None
# All Airlines not in our dataset
# Reading data from '2015'
# 1 Hawaiian 88.4
# Hawaiian not in our dataset
# 2 Alaska  86.42
# Alaska  not in our dataset
# 3 Delta  85.89
# 4 Combined American-US Airways 80.06172819479636
# Combined American-US Airways not in our dataset
# None    American   80.25741614140256
# None    US Airways* 79.3468032106283
# after removing start airline name    US Airways
#    US Airways not in our dataset
# 5 Virgin America 79.92
# Virgin America not in our dataset
# 6 SkyWest  79.72
# 7 Southwest  79.71
# 8 United  78.15
# 9 ExpressJet  77.9
# ExpressJet  not in our dataset
# 10 JetBlue 75.97
# 11 Envoy  74.07
# 12 Frontier 73.23
# Frontier not in our dataset
# 13 Spirit  68.98
# Spirit  not in our dataset
# None All Airlines 79.92
# All Airlines not in our dataset
# Reading data from '2016'
# 1 Hawaiian   91.08 None None
# Hawaiian   not in our dataset
# 2 Alaska   87.33 None None
# Alaska   not in our dataset
# 3 Delta  86.48 None None
# 4 SkyWest   82.28 None None
# 5 United  81.71 None None
# 6 Southwest 80.8 None None
# 7 ExpressJet   79.81 None None
# ExpressJet   not in our dataset
# 8 American 79.38 None None
# 9 Virgin America 76.21 None None
# Virgin America not in our dataset
# 10 Frontier   76.02 None None
# Frontier   not in our dataset
# 11 JetBlue  75.01 None None
# 12 Spirit 74.32 None None
# Spirit not in our dataset
# None All Airlines 81.42 None None
# All Airlines not in our dataset
# Reading data from '2017'
# 1 Hawaiian   88.22 None None
# Hawaiian   not in our dataset
# 2 Delta  85.4 None None
# 3 Alaska   82.55 None None
# Alaska   not in our dataset
# 4 United  82.06 None None
# 5 American 80.35 None None
# 6 SkyWest   80.01 None None
# 7 Southwest 78.66 None None
# 8 Frontier   78.34 None None
# Frontier   not in our dataset
# 9 ExpressJet   77.3 None None
# ExpressJet   not in our dataset
# 10 Spirit 77.09 None None
# Spirit not in our dataset
# 11 JetBlue  71.35 None None
# 12 Virgin America 70.01 None None
# Virgin America not in our dataset
# None All Airlines 80.18 None None
# All Airlines not in our dataset
# Reading data from 'Marketing 2018'
# Skipping this sheet, as it contains marketing on time arrival percentage
# Reading data from 'Operating 2018'
# 1 Hawaiian 89.28 None None
# Hawaiian not in our dataset
# 2 Delta 85.71 None None
# 3 Alaska* 82.15434022571375 None None
# after removing start airline name Alaska
# Alaska not in our dataset
# None   Alaska   82.48135383563707 None None
#   Alaska   not in our dataset
# None   Virgin America (1Q only) 77.60611205432937 None None
#   Virgin America (1Q only) not in our dataset
# 4 Spirit 81.08 None None
# Spirit not in our dataset
# 5 SkyWest  79.8 None None
# 6 United  79.68 None None
# 7 Endeavor 79.3 None None
# 8 Southwest 79.2 None None
# 9 Republic 78.57 None None
# 10 American 78.39 None None
# 11 Mesa 77.35 None None
# 12 Allegiant 76.87 None None
# Allegiant not in our dataset
# 13 Envoy  76.82 None None
# 14 ExpressJet  76.45 None None
# ExpressJet  not in our dataset
# 15 PSA  75.28 None None
# 16 JetBlue  70.96 None None
# 17 Frontier  69.39 None None
# Frontier  not in our dataset
# None All Airlines 79.38 None None
# All Airlines not in our dataset
# Reading data from 'Marketing 2019'
# Skipping this sheet, as it contains marketing on time arrival percentage
# Reading data from 'Operating 2019'
# 1 Hawaiian 88.34 None
# Hawaiian not in our dataset
# 2 Delta 85.18 None
# 3 Endeavor 80.93 None
# 4 Alaska 80.3 None
# Alaska not in our dataset
# 5 Southwest 80.24 None
# 6 Spirit 79.52 None
# Spirit not in our dataset
# 7 SkyWest  79.23 None
# 8 Allegiant 78.73 None
# Allegiant not in our dataset
# 9 Republic 78.66 None
# 10 PSA  78.09 None
# 11 United  77.74 None
# 12 American 77.01 None
# 13 Mesa 76.31 None
# 14 Envoy  76.09 None
# 15 JetBlue  73.5 None
# 16 Frontier  73.14 None
# Frontier  not in our dataset
# 17 ExpressJet  70.64 None
# ExpressJet  not in our dataset
# None All Airlines 79.21 None
# All Airlines not in our dataset
# Reading data from 'Marketing 2020'
# Skipping this sheet, as it contains marketing on time arrival percentage
# Reading data from 'Operating 2020'
# 1 Endeavor 89.16 None
# 2 Hawaiian 87.97 None
# Hawaiian not in our dataset
# 3 Republic 86.93 None
# 4 Spirit 86.61 None
# Spirit not in our dataset
# 5 Delta 86.32 None
# 6 Southwest 85.98 None
# 7 SkyWest  85.89 None
# 8 Alaska 84.85 None
# Alaska not in our dataset
# 9 Frontier  83.87 None
# Frontier  not in our dataset
# 10 United  83.56 None
# 11 American 83.37 None
# 12 JetBlue  82.14 None
# 13 Envoy  81.98 None
# 14 ExpressJet*  81.84 None
# after removing start airline name ExpressJet
# ExpressJet  not in our dataset
# 15 Mesa 81.61 None
# 16 PSA  79.3 None
# 17 Allegiant 71.33 None
# Allegiant not in our dataset
# None All Airlines 84.63 None
# All Airlines not in our dataset
# Reading data from 'Marketing 2021'
# Skipping this sheet, as it contains marketing on time arrival percentage
# Reading data from 'Operating 2021'
# 1 Endeavor Air 90.98
# 2 Hawaiian Airlines 90.15
# Hawaiian Airlines not in our dataset
# 3 Delta Air Lines 87.85
# 4 Horizon Air 85.26
# Horizon Air not in our dataset
# 5 PSA Airlines 84.52
# 6 Republic Airways 84.35
# 7 SkyWest Airlines 82.45
# 8 Envoy Air 82.32
# 9 United Airlines 81.34
# 10 Alaska Airlines 81.22
# Alaska Airlines not in our dataset
# 11 American Airlines 80.53
# 12 Mesa Airlines 77.14
# 13 Spirit Airlines 76.74
# Spirit Airlines not in our dataset
# 14 Frontier Airlines 76.64
# Frontier Airlines not in our dataset
# 15 Southwest Airlines 75.78
# 16 JetBlue Airways 72.31
# 17 Allegiant Air 68.26
# Allegiant Air not in our dataset
# Reading data from 'Marketing 2022'
# Skipping this sheet, as it contains marketing on time arrival percentage
# Reading data from 'Operating 2022'
# 1 Delta Air Lines 82.53
# 2 Horizon Air 81.79
# Horizon Air not in our dataset
# 3 SkyWest Airlines 81.61
# 4 Envoy Air 80.65
# 5 Endeavor Air 80.53
# 6 United Airlines 79.01
# 7 PSA Airlines 77.96
# 8 Mesa Airlines 77.43
# 9 Alaska Airlines 77.28
# Alaska Airlines not in our dataset
# 10 Republic Airways 76.42
# 11 Hawaiian Airlines 75.77
# Hawaiian Airlines not in our dataset
# 12 American Airlines 74.94
# 13 Southwest Airlines 73.18
# 14 Spirit Airlines 72.96
# Spirit Airlines not in our dataset
# 15 Frontier Airlines 66.1
# Frontier Airlines not in our dataset
# 16 JetBlue Airways 64.63
# 17 Allegiant Air 63.39
# Allegiant Air not in our dataset
# Reading data from 'Marketing 2023'
# Skipping this sheet, as it contains marketing on time arrival percentage
# Reading data from 'Operating 2023'
# 1 Republic Airways 84.35
# 2 Endeavor Air 84.11
# 3 Delta Air Lines 82.61
# 4 SkyWest Airlines 82.46
# 5 PSA Airlines 82.06
# 6 Envoy Air 80.84
# 7 Alaska Airlines 79.48
# Alaska Airlines not in our dataset
# 8 United Airlines 78.07
# 9 Southwest Airlines 77.25
# 10 American Airlines 75.94
# 11 Hawaiian Airlines 75.2
# Hawaiian Airlines not in our dataset
# 12 Allegiant Air 73.37
# Allegiant Air not in our dataset
# 13 Spirit Airlines  69.51
# Spirit Airlines  not in our dataset
# 14 JetBlue Airways 67.08
# 15 Frontier Airlines 66.99
# Frontier Airlines not in our dataset
# {'2006': {'Southwest': 80.23, 'Skywest': 76.78, 'Delta': 76.3, 'American': 71.48, 'United': 73.86, 'JetBlue': 73.33, 'Mesa': 72.9}, '2007': {'Southwest': 80.12, 'Delta': 76.89, 'Skywest': 75.68, 'Mesa': 73.1, 'United': 70.33, 'JetBlue': 70.1, 'American': 68.74}, '2008': {'Southwest': 80.48, 'Skywest': 78.97, 'Delta': 76.36, 'Mesa': 72.95, 'JetBlue': 72.87, 'American': 69.84, 'United': 71.61}, '2009': {'Southwest': 83.0, 'Skywest': 82.11, 'United': 80.98, 'Mesa': 79.13, 'Delta': 78.56, 'JetBlue': 77.45, 'American': 77.21}, '2010': {'United': 85.16, 'Mesa': 83.32, 'American': 77.05, 'Southwest': 79.46, 'Skywest': 79.05, 'Delta': 77.37, 'JetBlue': 75.68}, '2011': {'Mesa': 83.73, 'Southwest': 81.33, 'United': 80.16, 'Skywest': 79.34, 'American': 76.35, 'Delta': 75.15, 'JetBlue': 73.34}, '2012': {'Delta': 86.54, 'Mesa': 85.0, 'Southwest': 83.13, 'American': 76.94, 'Skywest': 81.61, 'JetBlue': 79.13, 'United': 77.35}, '2013': {'Delta': 84.51, 'Endeavor': 80.27, 'Skywest': 79.66, 'United': 79.27, 'American': 72.1, 'Mesa': 77.39, 'Southwest': 76.7, 'JetBlue': 74.44}, '2014': {'Delta': 83.71, 'Skywest': 76.35, 'United': 75.99, 'American': 75.79, 'JetBlue': 75.43, 'Southwest': 73.01, 'Envoy': 68.79}, '2015': {'Delta': 85.89, 'American': 80.26, 'Skywest': 79.72, 'Southwest': 79.71, 'United': 78.15, 'JetBlue': 75.97, 'Envoy': 74.07}, '2016': {'Delta': 86.48, 'Skywest': 82.28, 'United': 81.71, 'Southwest': 80.8, 'American': 79.38, 'JetBlue': 75.01}, '2017': {'Delta': 85.4, 'United': 82.06, 'American': 80.35, 'Skywest': 80.01, 'Southwest': 78.66, 'JetBlue': 71.35}, '2018': {'Delta': 85.71, 'Skywest': 79.8, 'United': 79.68, 'Endeavor': 79.3, 'Southwest': 79.2, 'Republic': 78.57, 'American': 78.39, 'Mesa': 77.35, 'Envoy': 76.82, 'PSA': 75.28, 'JetBlue': 70.96}, '2019': {'Delta': 85.18, 'Endeavor': 80.93, 'Southwest': 80.24, 'Skywest': 79.23, 'Republic': 78.66, 'PSA': 78.09, 'United': 77.74, 'American': 77.01, 'Mesa': 76.31, 'Envoy': 76.09, 'JetBlue': 73.5}, '2020': {'Endeavor': 89.16, 'Republic': 86.93, 'Delta': 86.32, 'Southwest': 85.98, 'Skywest': 85.89, 'United': 83.56, 'American': 83.37, 'JetBlue': 82.14, 'Envoy': 81.98, 'Mesa': 81.61, 'PSA': 79.3}, '2021': {'Endeavor': 90.98, 'Delta': 87.85, 'PSA': 84.52, 'Republic': 84.35, 'Skywest': 82.45, 'Envoy': 82.32, 'United': 81.34, 'American': 80.53, 'Mesa': 77.14, 'Southwest': 75.78, 'JetBlue': 72.31}, '2022': {'Delta': 82.53, 'Skywest': 81.61, 'Envoy': 80.65, 'Endeavor': 80.53, 'United': 79.01, 'PSA': 77.96, 'Mesa': 77.43, 'Republic': 76.42, 'American': 74.94, 'Southwest': 73.18, 'JetBlue': 64.63}, '2023': {'Republic': 84.35, 'Endeavor': 84.11, 'Delta': 82.61, 'Skywest': 82.46, 'PSA': 82.06, 'Envoy': 80.84, 'United': 78.07, 'Southwest': 77.25, 'American': 75.94, 'JetBlue': 67.08}}

# %%
# adding minimum reported percentage for the years airlines did not report on time arrival percentage
minimum_on_time_arr_pct = {}
for year, airline_data in airline_on_time_arr_pct_data.items():
    # print(year)
    # print(airline_data)
    for airline in airline_data:
        if airline not in minimum_on_time_arr_pct:
            minimum_on_time_arr_pct[airline] = airline_data[airline]
        else:
            min = minimum_on_time_arr_pct[airline]
            current_val = airline_data[airline]
            if current_val < min:
                # min = current_val
                minimum_on_time_arr_pct[airline] = current_val

print('#### minimum percentage of on-time flights #####')
# print(minimum_on_time_arr_pct)

for year in airline_on_time_arr_pct_data:
    airline_data = airline_on_time_arr_pct_data[year].copy()
    # print(airline_data)
    for airline in list_of_airlines:
        if airline not in airline_data:
            airline_data[airline] = minimum_on_time_arr_pct[airline]
    airline_on_time_arr_pct_data[year] = airline_data
        
print('### FINAL ON TIME PERCENTAGE DATA ####')
# print(airline_on_time_arr_pct_data)
# Out:
# #### minimum percentage of on-time flights #####
# ### FINAL ON TIME PERCENTAGE DATA ####

# %%
#convert airline name to airline code 
copy_air_line_on_time_arr_pct_data = {}
for year in airline_on_time_arr_pct_data:
    # copy_air_line_on_time_arr_pct_data[year] = {}
    copy_data = {}
    airline_data = airline_on_time_arr_pct_data[year]
    for airline in airline_data:
        airline_code = airline_name_code_map[airline]
        copy_data[airline_code] = airline_data[airline]
    copy_air_line_on_time_arr_pct_data[year] = copy_data
# copy_air_line_on_time_arr_pct_data

# %%
# Add airline arrival on time percentage column
with open('airline_on_time_arr_pct.json', 'w') as json_file:
    json.dump(copy_air_line_on_time_arr_pct_data, json_file, indent=4)

# json.dump(airport_on_time_dep_pct, indent=4)

# %%
airport_dep_file = open('airport_on_time_dep_pct.json', 'r')
airport_ranking_data = json.load(airport_dep_file)

airline_arr_file = open('airline_on_time_arr_pct.json', 'r')
airline_ranking_data = json.load(airline_arr_file)

# %%
#put weather data, airport on time dep pct, because you're processing date and airport origin here. 
def addDepPercentage(dateStr, origin):
    year = str(datetime.strptime(dateStr, '%m/%d/%Y').year)
    airport_on_time_dep_rate = airport_ranking_data[year][origin]
    return airport_on_time_dep_rate

def addArrPercentage(dateStr, carrier_code):
    year = str(datetime.strptime(dateStr, '%m/%d/%Y').year)
    airport_on_time_dep_rate = airline_ranking_data[year][carrier_code]
    return airport_on_time_dep_rate

# %%
# combinned_df = pd.DataFrame()
# if RawDataProcessing:
dataDir = 'data/arrivals/'
fileNames = os.listdir(dataDir)
dfList = []
for file in fileNames:
    filePath = dataDir + file
    print('Processing file {}'.format(filePath))
    if Path(filePath).is_dir():
        print('Skipping the directory {}'.format(filePath))
        continue
    raw_df = pd.read_csv(filePath)
    # raw_df.head()

    airline_df = pd.DataFrame()
    #dropping flights other than MCO, ORD, and JFK 
    # to keep additional filters (jetblue['Origin Airport'] == 'MCO') | (jetblue['Origin Airport'] == 'ORD') |
    filtered_data  = raw_df[(raw_df['Origin Airport'] == 'MCO') | (raw_df['Origin Airport'] == 'JFK') | (raw_df['Origin Airport'] == 'ORD')].copy()
    # filtered_data['Origin Airport'].unique()
    airline_df['DATE'] = filtered_data['Date (MM/DD/YYYY)']
    airline_df['DAY'] = [findDayOfWeek(date) for date in filtered_data['Date (MM/DD/YYYY)']]
    
    filtered_data['Flight Number'] = [flightNoStr(flightNo) for flightNo in filtered_data['Flight Number']]
    filtered_data['Flight No'] = filtered_data['Carrier Code'].str.cat(filtered_data['Flight Number'], sep=' ')
    airline_df['FLIGHT NUMBER'] = filtered_data['Flight No']

    airline_df['ORIGIN'] = filtered_data['Origin Airport']
    
    #converting time data to minutes
    filtered_data['Scheduled Arrival Time'] = [to_minutes(s) for s in filtered_data['Scheduled Arrival Time']] #to_minutes(step_1['Scheduled Arrival Time'])
    filtered_data['Actual Arrival Time'] = [to_minutes(s) for s in filtered_data['Actual Arrival Time']]
    filtered_data['Wheels-on Time'] = [to_minutes(s) for s in filtered_data['Wheels-on Time']]

    filtered_data['Scheduled Departure Time'] = filtered_data['Scheduled Arrival Time'] - filtered_data['Scheduled Elapsed Time (Minutes)']
    airline_df['DEPARTURE TIME'] = filtered_data['Scheduled Departure Time']
    airline_df['ARRIVAL TIME'] = filtered_data['Scheduled Arrival Time']
    # jetblue_df
    airline_df = airline_df[airline_df['ARRIVAL TIME']>=0] ##dropping data where flight departed one earlier date

    airline_df['CARRIER DELAY'] = filtered_data['Delay Carrier (Minutes)']
    airline_df['WEATHER DELAY'] = filtered_data['Delay Weather (Minutes)']

    airline_df['AIRPORT YEARLY ON-TIME DEP PERCENTAGE'] = [addDepPercentage(date, origin) for date, origin in zip(filtered_data['Date (MM/DD/YYYY)'], filtered_data['Origin Airport'])]
    
    airline_df['AIRLINE YEARLY ON-TIME ARR PERCENTAGE'] = [addArrPercentage(date, carrier_code) for date, carrier_code in zip(filtered_data['Date (MM/DD/YYYY)'], filtered_data['Carrier Code'])]
    
    # filtered_data['Arrival Delay (Minutes)']
    airline_df['ARRIVAL STATUS'] = [classifyDelay(delay) for delay in filtered_data['Arrival Delay (Minutes)']]

    # airline_df
    dfList.append(airline_df)
    
    # break
    # raw_data = pd.read_csv(file)
combined_df=pd.concat(dfList, ignore_index=True)
combined_df['DEPARTURE TIME'] = combined_df['DEPARTURE TIME'].astype(int)
# combined_df.to_csv('data/combined_arrival_data.csv', index=False)
combined_df
# Out:
# Processing file data/arrivals/Mesa_Airlines.csv
# Processing file data/arrivals/JetBlue_Airlines.csv
# Processing file data/arrivals/Endeavor_Air.csv
# Processing file data/arrivals/Southwest_Airlines.csv
# Processing file data/arrivals/United_Airlines.csv
# Processing file data/arrivals/PSA_Airlines.csv
# Processing file data/arrivals/Envoy_Airlines.csv
# Processing file data/arrivals/Skywest_Airline.csv
# Processing file data/arrivals/.ipynb_checkpoints
# Skipping the directory data/arrivals/.ipynb_checkpoints
# Processing file data/arrivals/Republic_Airline.csv
# Processing file data/arrivals/American_Airlines.csv
# Processing file data/arrivals/Delta_Airlines.csv
#              DATE        DAY FLIGHT NUMBER ORIGIN  DEPARTURE TIME  \
# 0      03/01/2009     Sunday       YV 7151    ORD             420
# 1      03/01/2010     Monday       YV 7287    ORD            1067
# 2      03/01/2011    Tuesday       YV 7244    ORD             871
# 3      03/01/2012   Thursday       YV 3734    ORD            1256
# 4      03/01/2013     Friday       YV 3731    ORD             895
# ...           ...        ...           ...    ...             ...
# 14082  05/29/2019  Wednesday       AA 1488    ORD            1195
# 14083  05/30/2019   Thursday       AA 1488    ORD            1195
# 14084  05/31/2019     Friday       AA 1488    ORD            1195
# 14085  04/09/2011   Saturday       DL 2033    JFK            1310
# 14086  04/10/2011     Sunday       DL 2050    JFK             510
#
#        ARRIVAL TIME  CARRIER DELAY  WEATHER DELAY  \
# 0               526           0.00           0.00
# 1              1167           0.00           0.00
# 2               970           0.00           0.00
# 3              1359           0.00           0.00
# 4               997           0.00         116.00
# ...             ...            ...            ...
# 14082          1302           0.00           0.00
# 14083          1302           7.00           0.00
# 14084          1302           0.00           0.00
# 14085          1398           0.00           0.00
# 14086           588           0.00           0.00
#
#        AIRPORT YEARLY ON-TIME DEP PERCENTAGE  \
# 0                                      78.21
# 1                                      77.53
# 2                                      74.40
# 3                                      76.58
# 4                                      70.37
# ...                                      ...
# 14082                                  74.94
# 14083                                  74.94
# 14084                                  74.94
# 14085                                  77.51
# 14086                                  77.51
#
#        AIRLINE YEARLY ON-TIME ARR PERCENTAGE  ARRIVAL STATUS
# 0                                      79.13               0
# 1                                      83.32               0
# 2                                      83.73               2
# 3                                      85.00               2
# 4                                      77.39               1
# ...                                      ...             ...
# 14082                                  77.01               2
# 14083                                  77.01               1
# 14084                                  77.01               1
# 14085                                  75.15               0
# 14086                                  75.15               0
#
# [14087 rows x 11 columns]

# %%
combined_df.to_csv('data/combined_arrival_data.csv', index=False)

# %%
# if RawDataProcessing:
dates = combined_df['DATE'].unique()
# finalData =  pd.DataFrame()
# MCO_flightList = []
# JFK_flightList = []
# ORD_flightList = []
totalFlightList = []
totalFlights = 0
for date in dates:
    flightList_MCO = combined_df[(combined_df['DATE'] == date) & (combined_df['ORIGIN'] == 'MCO')]
    sortedList_MCO = flightList_MCO.sort_values(by='DEPARTURE TIME', ascending=True)
    mco_f = sortedList_MCO.shape[0]
    # print('{} flights on date {} from MCO'.format(mco_f, date))
    # sortedList_MCO
    sortedList_MCO['previous_flight_status'] = sortedList_MCO['ARRIVAL STATUS'].shift(periods=1)
    # sortedList_MCO
    totalFlightList.append(sortedList_MCO)

    flightList_JFK = combined_df[(combined_df['DATE'] == date) & (combined_df['ORIGIN'] == 'JFK')]
    sortedList_JFK = flightList_JFK.sort_values(by='DEPARTURE TIME', ascending=True)
    jfk_f = sortedList_JFK.shape[0]
    # print('{} flights on date {} from JFK'.format(jfk_f, date))
    # sortedList_JFK
    sortedList_JFK['previous_flight_status'] = sortedList_JFK['ARRIVAL STATUS'].shift(periods=1)
    # sortedList_JFK
    totalFlightList.append(sortedList_JFK)

    flightList_ORD = combined_df[(combined_df['DATE'] == date) & (combined_df['ORIGIN'] == 'ORD')]
    sortedList_ORD = flightList_ORD.sort_values(by='DEPARTURE TIME', ascending=True)
    ord_f = sortedList_ORD.shape[0]
    # print('{} flights on date {} from ORD'.format(ord_f, date))
    # sortedList_ORD
    sortedList_ORD['previous_flight_status'] = sortedList_ORD['ARRIVAL STATUS'].shift(periods=1)
    # sortedList_ORD
    totalFlightList.append(sortedList_ORD)
    flightsOnDay = mco_f + jfk_f + ord_f
    # print('{} flights on date {}'.format(flightsOnDay, date))
    totalFlights = totalFlights + flightsOnDay
    # if i==5:
    #     break
    # i+=1
print('{} flights in total'.format(totalFlights))
finalData = pd.concat(totalFlightList, ignore_index=True) 
finalData.fillna(0, inplace=True)
finalData['DEPARTURE TIME'] = finalData['DEPARTURE TIME'].astype(int)
finalData['previous_flight_status'] = finalData['previous_flight_status'].astype(int)
finalData.to_csv('data/combined_data_with_prev_flight_status.csv', index=False)
    # finalData = pd.concat([finalData, sortedList], ignore_index=True)
# finalData
# Out:
# 14087 flights in total

# %%
data_1 = pd.read_csv('data/combined_arrival_data.csv')

# flight_data.columns
# flight_data['FLIGHT NUMBER'].unique().shape
data_1.isna().sum()
# data_1 = data_1.drop(columns = ['DATE','AIRPORT YEARLY ON-TIME DEP PERCENTAGE', 'AIRLINE YEARLY ON-TIME ARR PERCENTAGE', 'CARRIER DELAY', 'WEATHER DELAY', 'FLIGHT NUMBER'])
# data_1 = data_1.drop(columns = ['DATE','AIRPORT YEARLY ON-TIME DEP PERCENTAGE', 'AIRLINE YEARLY ON-TIME ARR PERCENTAGE', 'FLIGHT NUMBER'])
# data_1 = data_1.drop(columns = ['DATE','CARRIER DELAY', 'WEATHER DELAY', 'FLIGHT NUMBER'])
data_1 = data_1.drop(columns = ['DATE', 'FLIGHT NUMBER'])
data_1.head()
# Out:
# DATE                                     0
# DAY                                      0
# FLIGHT NUMBER                            0
# ORIGIN                                   0
# DEPARTURE TIME                           0
# ARRIVAL TIME                             0
# CARRIER DELAY                            0
# WEATHER DELAY                            0
# AIRPORT YEARLY ON-TIME DEP PERCENTAGE    0
# AIRLINE YEARLY ON-TIME ARR PERCENTAGE    0
# ARRIVAL STATUS                           0
# dtype: int64
#         DAY ORIGIN  DEPARTURE TIME  ARRIVAL TIME  CARRIER DELAY  \
# 0    Sunday    ORD             420           526           0.00
# 1    Monday    ORD            1067          1167           0.00
# 2   Tuesday    ORD             871           970           0.00
# 3  Thursday    ORD            1256          1359           0.00
# 4    Friday    ORD             895           997           0.00
#
#    WEATHER DELAY  AIRPORT YEARLY ON-TIME DEP PERCENTAGE  \
# 0           0.00                                  78.21
# 1           0.00                                  77.53
# 2           0.00                                  74.40
# 3           0.00                                  76.58
# 4         116.00                                  70.37
#
#    AIRLINE YEARLY ON-TIME ARR PERCENTAGE  ARRIVAL STATUS
# 0                                  79.13               0
# 1                                  83.32               0
# 2                                  83.73               2
# 3                                  85.00               2
# 4                                  77.39               1

# %%
data_2 = pd.read_csv('data/combined_data_with_prev_flight_status.csv')
# data_2.head()
# flight_data.columns
# flight_data['FLIGHT NUMBER'].unique().shape
data_2.isna().sum()
data_2 = data_2.drop(columns = ['DATE', 'FLIGHT NUMBER'])
data_2.head()
# Out:
# DATE                      0
# DAY                       0
# FLIGHT NUMBER             0
# ORIGIN                    0
# DEPARTURE TIME            0
# ARRIVAL TIME              0
# ARRIVAL STATUS            0
# previous_flight_status    0
# dtype: int64
#       DAY ORIGIN  DEPARTURE TIME  ARRIVAL TIME  ARRIVAL STATUS  \
# 0  Sunday    MCO             776           935               2
# 1  Sunday    MCO            1095          1253               0
# 2  Sunday    JFK             405           475               1
# 3  Sunday    JFK             670           745               2
# 4  Sunday    JFK            1020          1112               2
#
#    previous_flight_status
# 0                       0
# 1                       2
# 2                       0
# 3                       1
# 4                       2

# %%
#Building XGBoost model using the finalData
encoded_data_1 = pd.get_dummies(data_1.drop(columns=['ARRIVAL STATUS']), drop_first=True)
encoded_data_1.head()
# Out:
#    DEPARTURE TIME  ARRIVAL TIME  CARRIER DELAY  WEATHER DELAY  \
# 0             420           526           0.00           0.00
# 1            1067          1167           0.00           0.00
# 2             871           970           0.00           0.00
# 3            1256          1359           0.00           0.00
# 4             895           997           0.00         116.00
#
#    AIRPORT YEARLY ON-TIME DEP PERCENTAGE  \
# 0                                  78.21
# 1                                  77.53
# 2                                  74.40
# 3                                  76.58
# 4                                  70.37
#
#    AIRLINE YEARLY ON-TIME ARR PERCENTAGE  DAY_Monday  DAY_Saturday  \
# 0                                  79.13       False         False
# 1                                  83.32        True         False
# 2                                  83.73       False         False
# 3                                  85.00       False         False
# 4                                  77.39       False         False
#
#    DAY_Sunday  DAY_Thursday  DAY_Tuesday  DAY_Wednesday  ORIGIN_MCO  \
# 0        True         False        False          False       False
# 1       False         False        False          False       False
# 2       False         False         True          False       False
# 3       False          True        False          False       False
# 4       False         False        False          False       False
#
#    ORIGIN_ORD
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
#Building XGBoost model using the finalData
encoded_data_2 = pd.get_dummies(data_2.drop(columns=['ARRIVAL STATUS']), drop_first=True)
encoded_data_2.head()
# Out:
#    DEPARTURE TIME  ARRIVAL TIME  previous_flight_status  DAY_Monday  \
# 0             776           935                       0       False
# 1            1095          1253                       2       False
# 2             405           475                       0       False
# 3             670           745                       1       False
# 4            1020          1112                       2       False
#
#    DAY_Saturday  DAY_Sunday  DAY_Thursday  DAY_Tuesday  DAY_Wednesday  \
# 0         False        True         False        False          False
# 1         False        True         False        False          False
# 2         False        True         False        False          False
# 3         False        True         False        False          False
# 4         False        True         False        False          False
#
#    ORIGIN_MCO  ORIGIN_ORD
# 0        True       False
# 1        True       False
# 2       False       False
# 3       False       False
# 4       False       False

# %%
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(encoded_data_1, data_1['ARRIVAL STATUS'], stratify = data_1['ARRIVAL STATUS'], test_size=0.2, random_state=42)
X_train_1.shape
X_test_1.shape
# Out:
# (11269, 14)
# (2818, 14)

# %%
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(encoded_data_2, data_2['ARRIVAL STATUS'], stratify = data_2['ARRIVAL STATUS'], test_size=0.2, random_state=42)
X_train_2.shape
X_test_2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(encoded_data_2, data_2['ARRIVAL STATUS'], stratify = data_2['ARRIVAL STATUS'], test_size=0.2, random_state=42)
#       2 X_train_2.shape
#       3 X_test_2.shape
#
# NameError: name 'encoded_data_2' is not defined

# %%
from sklearn.preprocessing import StandardScaler
scaler_1 = StandardScaler()
X_train_scaled_1 = pd.DataFrame(scaler_1.fit_transform(X_train_1), columns=X_train_1.columns, index=X_train_1.index)
X_test_scaled_1 = pd.DataFrame(scaler_1.transform(X_test_1), columns=X_test_1.columns, index=X_test_1.index)

scaler_total_1 = StandardScaler()
total_Data_scaled_1 = pd.DataFrame(scaler_total_1.fit_transform(encoded_data_1), columns=encoded_data_1.columns, index=encoded_data_1.index)
total_y_1 = data_1['ARRIVAL STATUS']
# X_test_scaled

# %%
# from sklearn.preprocessing import StandardScaler
scaler_2 = StandardScaler()
X_train_scaled_2 = pd.DataFrame(scaler_2.fit_transform(X_train_2), columns=X_train_2.columns, index=X_train_2.index)
X_test_scaled_2 = pd.DataFrame(scaler_2.transform(X_test_2), columns=X_test_2.columns, index=X_test_2.index)

scaler_total_2 = StandardScaler()
total_Data_scaled_2 = pd.DataFrame(scaler_total_2.fit_transform(encoded_data_2), columns=encoded_data_2.columns, index=encoded_data_2.index)
total_y_2 = data_2['ARRIVAL STATUS']
# X_test_scaled

# %%
# X_train_scaled.rename({'DEPARTURE TIME':'DEPARTURE_TIME', 'ARRIVAL TIME':'ARRIVAL_TIME'})
# X_test_scaled.rename({'DEPARTURE TIME':'DEPARTURE_TIME', 'ARRIVAL TIME':'ARRIVAL_TIME'})

# dtrain_class = xgb.DMatrix(X_train_scaled, y_train, enable_categorical=True)
# dtest_class = xgb.DMatrix(X_test_scaled, y_test, enable_categorical=True)

# %%
def accuracy_score(test_output):
    total_count = len(test_output)
    wrong_count = len(test_output[test_output['Predicted Arrival Status'] != test_output['ARRIVAL STATUS']])
    accuracy = wrong_count/total_count
    return accuracy*100

# %%
tree_methods = ['exact', 'hist', 'approx']
tree_depth = [4, 6, 7, 8, 10, 15]
learning_rates = [0.05, 0.1, 0.2, 0.3, 0.4]
gamma = [0, 0.1, 0.2]
reg_lambda = [0, 1, 10]
reg_alpha = [0, 0.1, 1]

best_accuracy_1 = 0
best_params_1 = {}

# %%
from sklearn.model_selection import GridSearchCV

# %%
xgb_clf = xgb.XGBClassifier()

# Define the hyperparameters grid for tuning
param_grid = {
    'gamma': [0, 0.1, 0.2, 0.4, 0.9],
    'reg_lambda': [0, 1, 10, 50, 100],
    'reg_alpha': [0, 0.1, 1]
    # 'learning_rates': [0.05, 0.1, 0.2, 0.3, 0.4],
    # 'tree_depth': [4, 6, 7, 8, 10, 15]
}

# Perform grid search with cross-validation
grid_search = GridSearchCV(estimator=xgb_clf, param_grid=param_grid, cv=3, scoring='accuracy')
grid_search.fit(X_train_scaled_1, y_train_1)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              param_grid={'gamma': [0, 0.1, 0.2, 0.4, 0.9],
#                          'reg_alpha': [0, 0.1, 1],
#                          'reg_lambda': [0, 1, 10, 50, 100]},
#              scoring='accuracy')
# Best Hyperparameters: {'gamma': 0.1, 'reg_alpha': 1, 'reg_lambda': 10}

# %%
params = best_params #{'gamma': 0.1, 'learning_rates': 0.05, 'reg_alpha': 1, 'reg_lambda': 10, 'tree_depth': 4}
xgbModel = xgb.XGBClassifier(**params)
# xgbModel = GradientBoostingClassifier()
# xgbModel = GradientBoostingClassifier()
xgbModel.fit(X_train_scaled_1, y_train_1)
y_pred = pd.DataFrame(xgbModel.predict(X_test_scaled_1), columns=['Predicted Arrival Status'], index=X_test_scaled_1.index)

test_output = y_pred.merge(y_test_1, left_index=True, right_index=True)
# test_output.head()
accuracy = accuracy_score(test_output)
print('Accuracy of the xgb model is {}'.format(accuracy))
# if accuracy > best_accuracy_1:
#     best_accuracy_1 = accuracy
#     best_params_1 = params
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.1, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)
# Accuracy of the xgb model is 39.56706884315117

# %%
for method in tree_methods:
    for depth in tree_depth:
        for lr in learning_rates:
            for gm in gamma:
                for lm in reg_lambda: 
                    params = {
                        "objective": "multi:softmax",
                        "tree_method": method,
                        "max_depth" : depth,
                        "learning_rate" : lr,
                        "n_estimators": 200,
                        "gamma": gm,
                        "reg_lambda": lm
                    }
                    xgbModel = xgb.XGBClassifier(**params)
                    # xgbModel = GradientBoostingClassifier()
                    # xgbModel = GradientBoostingClassifier()
                    xgbModel.fit(X_train_scaled_1, y_train_1)
                    y_pred = pd.DataFrame(xgbModel.predict(X_test_scaled_1), columns=['Predicted Arrival Status'], index=X_test_scaled_1.index)
                    
                    test_output = y_pred.merge(y_test_1, left_index=True, right_index=True)
                    # test_output.head()
                    accuracy = accuracy_score(test_output)
                    print('Accuracy of the xgb model is {}'.format(accuracy))
                    if accuracy > best_accuracy_1:
                        best_accuracy_1 = accuracy
                        best_params_1 = params
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[72], line 18
#      15 xgbModel = xgb.XGBClassifier(**params)
#      16 # xgbModel = GradientBoostingClassifier()
#      17 # xgbModel = GradientBoostingClassifier()
# ---> 18 xgbModel.fit(X_train_scaled_1, y_train_1)
#      19 y_pred = pd.DataFrame(xgbModel.predict(X_test_scaled_1), columns=['Predicted Arrival Status'], index=X_test_scaled_1.index)
#      21 test_output = y_pred.merge(y_test_1, left_index=True, right_index=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/sklearn.py:1519, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1491 (
#    1492     model,
#    1493     metric,
#    (...)
#    1498     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1499 )
#    1500 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1501     missing=self.missing,
#    1502     X=X,
#    (...)
#    1516     feature_types=self.feature_types,
#    1517 )
# -> 1519 self._Booster = train(
#    1520     params,
#    1521     train_dmatrix,
#    1522     self.get_num_boosting_rounds(),
#    1523     evals=evals,
#    1524     early_stopping_rounds=early_stopping_rounds,
#    1525     evals_result=evals_result,
#    1526     obj=obj,
#    1527     custom_metric=metric,
#    1528     verbose_eval=verbose,
#    1529     xgb_model=model,
#    1530     callbacks=callbacks,
#    1531 )
#    1533 if not callable(self.objective):
#    1534     self.objective = params["objective"]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:2050, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
# -> 2050     _check_call(
#    2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:282, in _check_call(ret)
#     271 """Check the return value of C API call
#     272
#     273 This function will raise exception when error occurs.
#    (...)
#     279     return value from API calls
#     280 """
#     281 if ret != 0:
# --> 282     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: Invalid Parameter format for min_split_loss expect float but value='[0.0, 0.1, 0.2]'

# %%
print('Best Accuracy using xgb model is {}'.format(best_accuracy_1))
print('Best Parameter using xgb model is {}'.format(best_params_1))
# Out:
# Best Accuracy using xgb model is 55.53584102200142
# Best Parameter using xgb model is {'objective': 'multi:softmax', 'tree_method': 'exact', 'max_depth': 15, 'learning_rate': 0.4, 'n_estimators': 200}

# %%
best_accuracy_2 = 0
best_params_2 = {}

# %%
for method in tree_methods:
    for depth in tree_depth:
        for lr in learning_rates:
            params = {
                "objective": "multi:softmax",
                "tree_method": method,
                "max_depth" : depth,
                "learning_rate" : lr,
                "n_estimators": 200
            }
            xgbModel = xgb.XGBClassifier(**params)
            # xgbModel = GradientBoostingClassifier()
            # xgbModel = GradientBoostingClassifier()
            xgbModel.fit(X_train_scaled_2, y_train_2)
            y_pred = pd.DataFrame(xgbModel.predict(X_test_scaled_2), columns=['Predicted Arrival Status'], index=X_test_scaled_2.index)
            
            test_output = y_pred.merge(y_test_2, left_index=True, right_index=True)
            # test_output.head()
            accuracy = accuracy_score(test_output)
            print('Accuracy of the xgb model is {}'.format(accuracy))
            if accuracy > best_accuracy_2:
                best_accuracy_2 = accuracy
                best_params_2 = params
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.17104329311568
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 50.67423704755145
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 50.851667849538686
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.95173882185947
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.12916962384671
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.06458481192335
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.70333569907736
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.342086586231375
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.59048970901349
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.37757274662882
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.8097941802697
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.12916962384671
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.12916962384671
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.98722498225692
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.909865152590484
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.845280340667145
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.413058907026254
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.94535131298793
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.76792051100071
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.619588360539396
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.342086586231375
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.37118523775728
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.87437899219305
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.86799148332151
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.619588360539396
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.44215755855216
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.44215755855216
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.690560681334276
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.619588360539396
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 54.009936124911285
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.06458481192335
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.242015613910574
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.66784953867991
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.022711142654366
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.525904897090136
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.419446415897795
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.98722498225692
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.022711142654366
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.95173882185947
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.59048970901349
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.59687721788503
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.76792051100071
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.76792051100071
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.519517388218595
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.05180979418027
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.16465578424414
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.30660042583393
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.696948190205816
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.909865152590484
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.016323633782825
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.235628105039034
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.80340667139816
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.98083747338538
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.98083747338538
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 54.04542228530873
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.86799148332151
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.76153300212917
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.93896380411639
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.513129879347055
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
# ...
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.17104329311568
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.63236337828248
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.37757274662882
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.08729595457772
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.193754435770046
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.916252661462025
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 51.98722498225692
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.4485450674237
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.122782114975166
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.47764371894961
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.59048970901349
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 52.59048970901349
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.1582682753726
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.30021291696239
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.193754435770046
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.619588360539396
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.903477643718944
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.37118523775728
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 54.009936124911285
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# Accuracy of the xgb model is 53.93896380411639

# %%
print('Best Accuracy using xgb model is {}'.format(best_accuracy_2))
print('Best Parameter using xgb model is {}'.format(best_params_2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 print('Best Accuracy using xgb model is {}'.format(best_accuracy_2))
#       2 print('Best Parameter using xgb model is {}'.format(best_params_2))
#
# NameError: name 'best_accuracy_2' is not defined

# %%
model_1 = xgb.XGBClassifier(**best_params_1)

model_1.fit(total_Data_scaled_1, total_y_1)


model_2 = xgb.XGBClassifier(**best_params_2)

model_2.fit(total_Data_scaled_2, total_y_2)
# y_pred = pd.DataFrame(xgbModel.predict(X_test_scaled), columns=['Predicted Arrival Status'], index=X_test.index)

# test_output = y_pred.merge(y_test, left_index=True, right_index=True)
# # test_output.head()
# accuracy = accuracy_score(test_output)
# print('Accuracy of the xgb model is {}'.format(accuracy))
# if accuracy > best_accuracy:
#     best_accuracy = accuracy
#     best_params = params
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)

# %%
test_data = pd.read_csv('CIS_662 _INITIAL_Predictions.csv', na_values=[''], keep_default_na=False)
# test_data.drop(columns=['DATE','FLIGHT NUMBER', 'ARRIVAL STATUS_Prev_flight_early', 'ARRIVAL STATUS_Prev_flight_ontime', 'ARRIVAL STATUS_Prev_flight_late'],inplace=True)
internal_test_data = pd.DataFrame(test_data.drop(columns=['DATE','FLIGHT NUMBER']), index=test_data.index)
test_data
internal_test_data
# Out:
#        DATE        DAY FLIGHT NUMBER ORIGIN DEPARTURE TIME ARRIVAL TIME  \
# 0   4/10/24  WEDNESDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 1   4/10/24  WEDNESDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 2   4/10/24  WEDNESDAY        B6 116    JFK        1:33 PM      2:50 PM
# 3   4/10/24  WEDNESDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 4   4/10/24  WEDNESDAY       WN 5285    MCO       11:05 AM      1:45 PM
# 5   4/10/24  WEDNESDAY        B6 656    MCO        1:35 PM      4:25 PM
# 6   4/11/24   THURSDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 7   4/11/24   THURSDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 8   4/11/24   THURSDAY        B6 116    JFK        1:33 PM      2:50 PM
# 9   4/11/24   THURSDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 10  4/11/24   THURSDAY       WN 5285    MCO       11:35 AM      2:20 PM
# 11  4/11/24   THURSDAY        B6 656    MCO        1:35 PM      4:25 PM
# 12  4/12/24     FRIDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 13  4/12/24     FRIDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 14  4/12/24     FRIDAY        B6 116    JFK        1:33 PM      2:50 PM
# 15  4/12/24     FRIDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 16  4/12/24     FRIDAY       WN 5285    MCO       11:35 AM      2:20 PM
# 17  4/12/24     FRIDAY        B6 656    MCO        1:35 PM      4:25 PM
# 18  4/13/24   SATURDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 19  4/13/24   SATURDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 20  4/13/24   SATURDAY        B6 116    JFK        1:12 PM      2:30 PM
# 21  4/13/24   SATURDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 22  4/13/24   SATURDAY        B6 656    MCO        1:35 PM      4:25 PM
#
#    ARRIVAL STATUS ARRIVAL STATUS_Prev_flight_early  \
# 0             NaN                               NA
# 1              NA                              NaN
# 2             NaN                               NA
# 3              NA                              NaN
# 4             NaN                               NA
# 5              NA                              NaN
# 6             NaN                               NA
# 7              NA                              NaN
# 8             NaN                               NA
# 9              NA                              NaN
# 10            NaN                               NA
# 11             NA                              NaN
# 12            NaN                               NA
# 13             NA                              NaN
# 14            NaN                               NA
# 15             NA                              NaN
# 16            NaN                               NA
# 17             NA                              NaN
# 18            NaN                               NA
# 19             NA                              NaN
# 20            NaN                               NA
# 21             NA                              NaN
# 22            NaN                               NA
#
#    ARRIVAL STATUS_Prev_flight_ontime ARRIVAL STATUS_Prev_flight_late
# 0                                 NA                              NA
# 1                                NaN                             NaN
# 2                                 NA                              NA
# 3                                NaN                             NaN
# 4                                 NA                              NA
# 5                                NaN                             NaN
# 6                                 NA                              NA
# 7                                NaN                             NaN
# 8                                 NA                              NA
# 9                                NaN                             NaN
# 10                                NA                              NA
# 11                               NaN                             NaN
# 12                                NA                              NA
# 13                               NaN                             NaN
# 14                                NA                              NA
# 15                               NaN                             NaN
# 16                                NA                              NA
# 17                               NaN                             NaN
# 18                                NA                              NA
# 19                               NaN                             NaN
# 20                                NA                              NA
# 21                               NaN                             NaN
# 22                                NA                              NA
#           DAY ORIGIN DEPARTURE TIME ARRIVAL TIME ARRIVAL STATUS  \
# 0   WEDNESDAY    ORD        6:52 PM      9:47 PM            NaN
# 1   WEDNESDAY    ORD        7:59 PM     10:52 PM             NA
# 2   WEDNESDAY    JFK        1:33 PM      2:50 PM            NaN
# 3   WEDNESDAY    JFK        2:55 PM      4:21 PM             NA
# 4   WEDNESDAY    MCO       11:05 AM      1:45 PM            NaN
# 5   WEDNESDAY    MCO        1:35 PM      4:25 PM             NA
# 6    THURSDAY    ORD        6:52 PM      9:47 PM            NaN
# 7    THURSDAY    ORD        7:59 PM     10:52 PM             NA
# 8    THURSDAY    JFK        1:33 PM      2:50 PM            NaN
# 9    THURSDAY    JFK        2:55 PM      4:21 PM             NA
# 10   THURSDAY    MCO       11:35 AM      2:20 PM            NaN
# 11   THURSDAY    MCO        1:35 PM      4:25 PM             NA
# 12     FRIDAY    ORD        6:52 PM      9:47 PM            NaN
# 13     FRIDAY    ORD        7:59 PM     10:52 PM             NA
# 14     FRIDAY    JFK        1:33 PM      2:50 PM            NaN
# 15     FRIDAY    JFK        2:55 PM      4:21 PM             NA
# 16     FRIDAY    MCO       11:35 AM      2:20 PM            NaN
# 17     FRIDAY    MCO        1:35 PM      4:25 PM             NA
# 18   SATURDAY    ORD        6:52 PM      9:47 PM            NaN
# 19   SATURDAY    ORD        7:59 PM     10:52 PM             NA
# 20   SATURDAY    JFK        1:12 PM      2:30 PM            NaN
# 21   SATURDAY    JFK        2:55 PM      4:21 PM             NA
# 22   SATURDAY    MCO        1:35 PM      4:25 PM            NaN
#
#    ARRIVAL STATUS_Prev_flight_early ARRIVAL STATUS_Prev_flight_ontime  \
# 0                                NA                                NA
# 1                               NaN                               NaN
# 2                                NA                                NA
# 3                               NaN                               NaN
# 4                                NA                                NA
# 5                               NaN                               NaN
# 6                                NA                                NA
# 7                               NaN                               NaN
# 8                                NA                                NA
# 9                               NaN                               NaN
# 10                               NA                                NA
# 11                              NaN                               NaN
# 12                               NA                                NA
# 13                              NaN                               NaN
# 14                               NA                                NA
# 15                              NaN                               NaN
# 16                               NA                                NA
# 17                              NaN                               NaN
# 18                               NA                                NA
# 19                              NaN                               NaN
# 20                               NA                                NA
# 21                              NaN                               NaN
# 22                               NA                                NA
#
#    ARRIVAL STATUS_Prev_flight_late
# 0                               NA
# 1                              NaN
# 2                               NA
# 3                              NaN
# 4                               NA
# 5                              NaN
# 6                               NA
# 7                              NaN
# 8                               NA
# 9                              NaN
# 10                              NA
# 11                             NaN
# 12                              NA
# 13                             NaN
# 14                              NA
# 15                             NaN
# 16                              NA
# 17                             NaN
# 18                              NA
# 19                             NaN
# 20                              NA
# 21                             NaN
# 22                              NA

# %%
def convert_to_24Hr(timeStr):
    if ('AM' not in  timeStr) and ('PM' not in timeStr):
        return timeStr
    time = timeStr.split(sep=' ')
    timeValue = time[0]
    hh_mm = timeValue.split(sep=':')
    hr = hh_mm[0]
    min = hh_mm[1]
    am_pm = time[1]
    if am_pm == 'PM':
        hr_int = int(hr) + 12
        hr = str(hr_int)
    return hr +':'+min

# %%
internal_test_data['DEPARTURE TIME'] = [convert_to_24Hr(x) for x in internal_test_data['DEPARTURE TIME']]
internal_test_data['DEPARTURE TIME'] = [to_minutes(x) for x in internal_test_data['DEPARTURE TIME']]
internal_test_data['ARRIVAL TIME'] = [convert_to_24Hr(x) for x in internal_test_data['ARRIVAL TIME']]
internal_test_data['ARRIVAL TIME'] = [to_minutes(x) for x in internal_test_data['ARRIVAL TIME']]

# %%
internal_test_data.head()
# internal_test_data = len(test_data)
# Out:
#          DAY ORIGIN  DEPARTURE TIME  ARRIVAL TIME ARRIVAL STATUS  \
# 0  WEDNESDAY    ORD            1132          1307            NaN
# 1  WEDNESDAY    ORD            1199          1372             NA
# 2  WEDNESDAY    JFK             813           890            NaN
# 3  WEDNESDAY    JFK             895           981             NA
# 4  WEDNESDAY    MCO             665           825            NaN
#
#   ARRIVAL STATUS_Prev_flight_early ARRIVAL STATUS_Prev_flight_ontime  \
# 0                               NA                                NA
# 1                              NaN                               NaN
# 2                               NA                                NA
# 3                              NaN                               NaN
# 4                               NA                                NA
#
#   ARRIVAL STATUS_Prev_flight_late
# 0                              NA
# 1                             NaN
# 2                              NA
# 3                             NaN
# 4                              NA

# %%
#dynamic training loop
for id in internal_test_data.index:
    day_of_flight = internal_test_data.loc[id,'DAY']
    origin = internal_test_data.loc[id,'ORIGIN']
    dep_time = internal_test_data.loc[id,'DEPARTURE TIME']
    arr_time = internal_test_data.loc[id,'ARRIVAL TIME']
    
    # test_row = pd.DataFrame(test_data.loc[i].copy())
    # test_row[]
    # day_of_flight = test_row.loc[0,'DAY']
    final_data_for_this_row = {}

    
    q1 = internal_test_data.loc[id, 'ARRIVAL STATUS']
    # print(status_qwery)
    if q1 != 'NA':
        columns=X_test_1.columns
        # new_test_row
        data_dict = {}
        data_dict['DEPARTURE TIME'] = [dep_time]
        data_dict['ARRIVAL TIME'] = [arr_time]
        data_dict['DAY_Monday'] = True if day_of_flight=='MONDAY' else False
        data_dict['DAY_Saturday'] = True if day_of_flight=='SATURDAY' else False
        data_dict['DAY_Sunday'] = True if day_of_flight=='SUNDAY' else False
        data_dict['DAY_Thursday'] = True if day_of_flight=='THURSDAY' else False
        data_dict['DAY_Tuesday'] = True if day_of_flight=='TUESDAY' else False
        data_dict['DAY_Wednesday'] = True if day_of_flight=='WEDNESDAY' else False
        data_dict['ORIGIN_MCO'] = True if origin == 'MCO' else False
        data_dict['ORIGIN_ORD'] = True if origin == 'ORD' else False
    
        test_df_1 = pd.DataFrame(data_dict) #use this dataframe to get prediction from model -1
        scaled_test_df_1 = scaler_total_1.transform(test_df_1)

        value = model_1.predict(scaled_test_df_1)
        if value == 0:
            # print('EARLY')
            test_data.loc[id,'ARRIVAL STATUS'] = 'EARLY'
        elif value == 1:
            # print('EARLY')
            test_data.loc[id,'ARRIVAL STATUS'] = 'ON-TIME'
        else:
            test_data.loc[id,'ARRIVAL STATUS'] = 'LATE'

        # test_data.loc[id]

    q2 = internal_test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_early']
    if q2 != 'NA':
        data_dict_2 = {}
        data_dict_2['DEPARTURE TIME'] = [dep_time]
        data_dict_2['ARRIVAL TIME'] = [arr_time]
        data_dict_2['previous_flight_status'] = [0]
        data_dict_2['DAY_Monday'] = True if day_of_flight=='MONDAY' else False
        data_dict_2['DAY_Saturday'] = True if day_of_flight=='SATURDAY' else False
        data_dict_2['DAY_Sunday'] = True if day_of_flight=='SUNDAY' else False
        data_dict_2['DAY_Thursday'] = True if day_of_flight=='THURSDAY' else False
        data_dict_2['DAY_Tuesday'] = True if day_of_flight=='TUESDAY' else False
        data_dict_2['DAY_Wednesday'] = True if day_of_flight=='WEDNESDAY' else False
        data_dict_2['ORIGIN_MCO'] = True if origin == 'MCO' else False
        data_dict_2['ORIGIN_ORD'] = True if origin == 'ORD' else False

        test_df_2 = pd.DataFrame(data_dict_2) #use this dataframe to get prediction from model-2
        scaled_test_df_2 = scaler_total_2.transform(test_df_2)

        value = model_2.predict(scaled_test_df_2)
        if value == 0:
            # print('EARLY')
            test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_early'] = 'EARLY'
        elif value == 1:
            # print('EARLY')
            test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_early'] = 'ON-TIME'
        else:
            test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_early'] = 'LATE'

    q3 = internal_test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_ontime']
    if q3 != 'NA':
        data_dict_3 = {}
        data_dict_3['DEPARTURE TIME'] = [dep_time]
        data_dict_3['ARRIVAL TIME'] = [arr_time]
        data_dict_3['previous_flight_status'] = [1]
        data_dict_3['DAY_Monday'] = True if day_of_flight=='MONDAY' else False
        data_dict_3['DAY_Saturday'] = True if day_of_flight=='SATURDAY' else False
        data_dict_3['DAY_Sunday'] = True if day_of_flight=='SUNDAY' else False
        data_dict_3['DAY_Thursday'] = True if day_of_flight=='THURSDAY' else False
        data_dict_3['DAY_Tuesday'] = True if day_of_flight=='TUESDAY' else False
        data_dict_3['DAY_Wednesday'] = True if day_of_flight=='WEDNESDAY' else False
        data_dict_3['ORIGIN_MCO'] = True if origin == 'MCO' else False
        data_dict_3['ORIGIN_ORD'] = True if origin == 'ORD' else False

        test_df_3 = pd.DataFrame(data_dict_3) #use this dataframe to get prediction from model-2
        scaled_test_df_3 = scaler_total_2.transform(test_df_3)

        value = model_2.predict(scaled_test_df_3)
        if value == 0:
            # print('EARLY')
            test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_ontime'] = 'EARLY'
        elif value == 1:
            # print('EARLY')
            test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_ontime'] = 'ON-TIME'
        else:
            test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_ontime'] = 'LATE'

        # test_data.loc[id]

    q4 = internal_test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_late']
    if q4 != 'NA':
        data_dict_4 = {}
        data_dict_4['DEPARTURE TIME'] = [dep_time]
        data_dict_4['ARRIVAL TIME'] = [arr_time]
        data_dict_4['previous_flight_status'] = [2]
        data_dict_4['DAY_Monday'] = True if day_of_flight=='MONDAY' else False
        data_dict_4['DAY_Saturday'] = True if day_of_flight=='SATURDAY' else False
        data_dict_4['DAY_Sunday'] = True if day_of_flight=='SUNDAY' else False
        data_dict_4['DAY_Thursday'] = True if day_of_flight=='THURSDAY' else False
        data_dict_4['DAY_Tuesday'] = True if day_of_flight=='TUESDAY' else False
        data_dict_4['DAY_Wednesday'] = True if day_of_flight=='WEDNESDAY' else False
        data_dict_4['ORIGIN_MCO'] = True if origin == 'MCO' else False
        data_dict_4['ORIGIN_ORD'] = True if origin == 'ORD' else False

        test_df_4 = pd.DataFrame(data_dict_4) #use this dataframe to get prediction from model-2
        scaled_test_df_4 = scaler_total_2.transform(test_df_4)

        value = model_2.predict(scaled_test_df_4)
        if value == 0:
            # print('EARLY')
            test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_late'] = 'EARLY'
        elif value == 1:
            # print('EARLY')
            test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_late'] = 'ON-TIME'
        else:
            test_data.loc[id, 'ARRIVAL STATUS_Prev_flight_late'] = 'LATE'

    # break
test_data
test_data.to_csv('CIS_662 _INITIAL_Predictions_Filled.csv', index=False)
# internal_test_data
# Out:
#        DATE        DAY FLIGHT NUMBER ORIGIN DEPARTURE TIME ARRIVAL TIME  \
# 0   4/10/24  WEDNESDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 1   4/10/24  WEDNESDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 2   4/10/24  WEDNESDAY        B6 116    JFK        1:33 PM      2:50 PM
# 3   4/10/24  WEDNESDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 4   4/10/24  WEDNESDAY       WN 5285    MCO       11:05 AM      1:45 PM
# 5   4/10/24  WEDNESDAY        B6 656    MCO        1:35 PM      4:25 PM
# 6   4/11/24   THURSDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 7   4/11/24   THURSDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 8   4/11/24   THURSDAY        B6 116    JFK        1:33 PM      2:50 PM
# 9   4/11/24   THURSDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 10  4/11/24   THURSDAY       WN 5285    MCO       11:35 AM      2:20 PM
# 11  4/11/24   THURSDAY        B6 656    MCO        1:35 PM      4:25 PM
# 12  4/12/24     FRIDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 13  4/12/24     FRIDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 14  4/12/24     FRIDAY        B6 116    JFK        1:33 PM      2:50 PM
# 15  4/12/24     FRIDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 16  4/12/24     FRIDAY       WN 5285    MCO       11:35 AM      2:20 PM
# 17  4/12/24     FRIDAY        B6 656    MCO        1:35 PM      4:25 PM
# 18  4/13/24   SATURDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 19  4/13/24   SATURDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 20  4/13/24   SATURDAY        B6 116    JFK        1:12 PM      2:30 PM
# 21  4/13/24   SATURDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 22  4/13/24   SATURDAY        B6 656    MCO        1:35 PM      4:25 PM
#
#    ARRIVAL STATUS ARRIVAL STATUS_Prev_flight_early  \
# 0           EARLY                               NA
# 1              NA                            EARLY
# 2         ON-TIME                               NA
# 3              NA                            EARLY
# 4           EARLY                               NA
# 5              NA                          ON-TIME
# 6           EARLY                               NA
# 7              NA                            EARLY
# 8         ON-TIME                               NA
# 9              NA                          ON-TIME
# 10        ON-TIME                               NA
# 11             NA                             LATE
# 12          EARLY                               NA
# 13             NA                            EARLY
# 14          EARLY                               NA
# 15             NA                          ON-TIME
# 16        ON-TIME                               NA
# 17             NA                          ON-TIME
# 18          EARLY                               NA
# 19             NA                            EARLY
# 20          EARLY                               NA
# 21             NA                            EARLY
# 22        ON-TIME                               NA
#
#    ARRIVAL STATUS_Prev_flight_ontime ARRIVAL STATUS_Prev_flight_late
# 0                                 NA                              NA
# 1                               LATE                            LATE
# 2                                 NA                              NA
# 3                              EARLY                         ON-TIME
# 4                                 NA                              NA
# 5                              EARLY                         ON-TIME
# 6                                 NA                              NA
# 7                               LATE                            LATE
# 8                                 NA                              NA
# 9                              EARLY                           EARLY
# 10                                NA                              NA
# 11                           ON-TIME                         ON-TIME
# 12                                NA                              NA
# 13                              LATE                           EARLY
# 14                                NA                              NA
# 15                             EARLY                           EARLY
# 16                                NA                              NA
# 17                             EARLY                         ON-TIME
# 18                                NA                              NA
# 19                              LATE                           EARLY
# 20                                NA                              NA
# 21                             EARLY                         ON-TIME
# 22                                NA                              NA
